# %% [markdown]
# <a href="https://colab.research.google.com/github/crazy85128x/hahow-python/blob/main/crawler_BeautifulSoup_%E9%89%85%E4%BA%A8%E7%B6%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 享駿爬蟲複習(普鴻)

# %% [markdown]
# ## 單則股市新聞爬蟲程式

# %%
import requests
# 對網址發送請求
url = "https://news.cnyes.com/news/id/4513224?exp=a"
res = requests.get(url)

# %%
res.text
# Out:
# '<!doctype html>\n<html lang="zh-TW" data-reactroot="" data-reactid="1" data-react-checksum="1936627177"><head data-reactid="2"><meta charset="utf-8" data-reactid="3"/><script data-reactid="4">(function setupTitleExp(a,b,c,d,e){function pickBall(a){var b=Math.random();return b<=a?b<=a/2?\'a\':\'b\':\'o\'}function bakeCookie(a,_ref){var b=_ref.name,c=_ref.value,e=_ref.maxAge,f=_ref.domain,g=[b+\'=\'+c,\'path=/\',\'max-age=\'+e,\'domain=\'+f].join(\';\');a.cookie=g}var f=new RegExp(e+\'=([^;]+)\'),g=new RegExp(\'^/news/id/[0-9]+\'),h=a.cookie.match(f),i=h&&(h=h[1]),j=b.search,k=!1;if(!i){var l=b.host,m=l.substring(l.indexOf(\'.\'));i=pickBall(c),bakeCookie(a,{name:e,value:i,maxAge:d,domain:m}),k=!0}if(b.pathname.match(g)&&(k=!1),j.match(/exp=.{1}/)&&(k=!1),k&&(\'a\'===i||\'b\'===i)){j=j.replace(/exp=[ab]/gi,\'\');var n=\'exp=\'+i;b.href=j?j+\'&\'+n:\'?\'+n}})(document, location, 86400000, 0.6, \'__exp__\')</script><meta property="fb:app_id" content="325242790993768" data-reactid="5"/><
# ...

# %%
# 解析html網頁原始碼的套件，吃網頁原始碼的變數res.text
from bs4 import BeautifulSoup

soup = BeautifulSoup(res.text)

# %%
# 爬取新聞標題
# find就是找出特定標籤
soup.find("h1").text
# Out:
# '鴻海10億美元打造5G亳米波連接器產線 進入調整測試階段'

# %%
# 爬取新聞發布時間
#soup.find("time")
soup.find("time").text
# Out:
# '2020/08/08 13:12'

# %%
# 爬取內文 
soup.find("p")
# Out:
# <p data-reactid="24">熱搜：</p>

# %%
# 找div標籤，{div 裡面的屬性}
soup.find("div", {"itemprop":"articleBody"})
# Out:
# <div class="_1UuP" data-reactid="276" itemprop="articleBody"><div class="_2E8y" data-reactid="277"><p>鴻海 (<a href="https://invest.cnyes.com/twstock/tws/2317">2317-TW</a>) 集團在中國昆山斥資逾 10 億<a href="https://invest.cnyes.com/forex/detail/usdtwd">美元</a>，打造的 5G 亳米波連接器產線，目前進入設備調整測試階段，預計投產放量後，年產值可望突破 400 億元。</p>
# <p>據了解，鴻海子公司富士康 (昆山) 電腦接插件公司，主要從事 5G 手機毫米波連接器的研發生産和銷售，鴻海先前也透過一連串的增資，加速擴展集團在 5G 關鍵零組件的版圖。</p>
# <p>鴻海旗下鴻騰全球營運長盧伯卿日前指出，面對復雜多變的全球經濟環境和日趨激烈的科技競爭態勢，昆山富士康全力穩生産拼經濟，同時順應未來産業升級發展趨勢，緊盯 5G 等新基建發展態勢，聚合 5G 相關産業鏈，打造 5G 産業生産基地，啟動高質量發展新動能。</p>
# <p>鴻海加速在 5G 相關應用，子公司 Fii 工業富聯 (601138-CN) 日前也與騰訊雲簽署戰略合作協議，共同推動 5G 通訊，數據中心、工業互聯網等新型基礎設施建設。</p>
# <hr style="height: 0; border-width: 1px; visibility: hidden"/></div><div class="_2E8y" data-reactid="278" style="display:none;"></div></div>

# %%
# soup.find("div", {"itemprop":"articleBody"}) 存入 body_div
body_div = soup.find("div", {"itemprop":"articleBody"})

# %%
#從body_div中找(p)標籤
body_div.find("p")
# Out:
# <p>鴻海 (<a href="https://invest.cnyes.com/twstock/tws/2317">2317-TW</a>) 集團在中國昆山斥資逾 10 億<a href="https://invest.cnyes.com/forex/detail/usdtwd">美元</a>，打造的 5G 亳米波連接器產線，目前進入設備調整測試階段，預計投產放量後，年產值可望突破 400 億元。</p>

# %%
# 找出所有的(p)
# strip()就是把一些空格根一些換行符號清乾淨
body_div.find_all("p")[2].text.strip()
# Out:
# '鴻海旗下鴻騰全球營運長盧伯卿日前指出，面對復雜多變的全球經濟環境和日趨激烈的科技競爭態勢，昆山富士康全力穩生産拼經濟，同時順應未來産業升級發展趨勢，緊盯 5G 等新基建發展態勢，聚合 5G 相關産業鏈，打造 5G 産業生産基地，啟動高質量發展新動能。'

# %%
# 將所有內文連在一起
content = ""
for p in body_div.find_all("p"):
  content = content + p.text.strip()
content
# Out:
# '鴻海 (2317-TW) 集團在中國昆山斥資逾 10 億美元，打造的 5G 亳米波連接器產線，目前進入設備調整測試階段，預計投產放量後，年產值可望突破 400 億元。據了解，鴻海子公司富士康 (昆山) 電腦接插件公司，主要從事 5G 手機毫米波連接器的研發生産和銷售，鴻海先前也透過一連串的增資，加速擴展集團在 5G 關鍵零組件的版圖。鴻海旗下鴻騰全球營運長盧伯卿日前指出，面對復雜多變的全球經濟環境和日趨激烈的科技競爭態勢，昆山富士康全力穩生産拼經濟，同時順應未來産業升級發展趨勢，緊盯 5G 等新基建發展態勢，聚合 5G 相關産業鏈，打造 5G 産業生産基地，啟動高質量發展新動能。鴻海加速在 5G 相關應用，子公司 Fii 工業富聯 (601138-CN) 日前也與騰訊雲簽署戰略合作協議，共同推動 5G 通訊，數據中心、工業互聯網等新型基礎設施建設。'

# %%
# 爬取網頁關鍵字 tag - 看不到的資訊
soup.find("meta", {"itemprop":"keywords"})["content"]
# Out:
# '鴻海,富士康,5G,毫米波,連接器,工業富聯'

# %%
# 彙整所有爬蟲程式碼
# 匯入套件'http請求'&'解析html網頁原始碼'
import requests
from bs4 import BeautifulSoup

# 定義url的變數(訪問的網址)
url = "https://news.cnyes.com/news/id/4513224?exp=a"
#用requests.get去跟伺服器互動取得網頁原始碼
res = requests.get(url) 
# 用BeautifulSoup把它還原出原本有的html格式(用特定的標籤)把資料找出來
soup = BeautifulSoup(res.text)
title = soup.find("h1").text
print(title)
time = soup.find("time").text
print(time)
body_div = soup.find("div", {"itemprop":"articleBody"})
body_div.find_all("p")
content = ""
for p in body_div.find_all("p"):
  content = content + p.text.strip()
print(content)
keywords = soup.find("meta", {"itemprop":"keywords"})["content"]
print(keywords)
# Out:
# 鴻海10億美元打造5G亳米波連接器產線 進入調整測試階段
# 2020/08/08 13:12
# 鴻海 (2317-TW) 集團在中國昆山斥資逾 10 億美元，打造的 5G 亳米波連接器產線，目前進入設備調整測試階段，預計投產放量後，年產值可望突破 400 億元。據了解，鴻海子公司富士康 (昆山) 電腦接插件公司，主要從事 5G 手機毫米波連接器的研發生産和銷售，鴻海先前也透過一連串的增資，加速擴展集團在 5G 關鍵零組件的版圖。鴻海旗下鴻騰全球營運長盧伯卿日前指出，面對復雜多變的全球經濟環境和日趨激烈的科技競爭態勢，昆山富士康全力穩生産拼經濟，同時順應未來産業升級發展趨勢，緊盯 5G 等新基建發展態勢，聚合 5G 相關産業鏈，打造 5G 産業生産基地，啟動高質量發展新動能。鴻海加速在 5G 相關應用，子公司 Fii 工業富聯 (601138-CN) 日前也與騰訊雲簽署戰略合作協議，共同推動 5G 通訊，數據中心、工業互聯網等新型基礎設施建設。
# 鴻海,富士康,5G,毫米波,連接器,工業富聯

# %% [markdown]
# ## 以 CSV 格式儲存資料

# %%
import csv
# 用with open來開啟csv，w為寫入，編碼為utf-8，取名為 f
with open('output.csv', 'w', encoding="utf-8") as f:
  # 建立 CSV 寫入器
  writer = csv.writer(f)

  # 寫入標頭資料
  writer.writerow(['標題', '發文時間', '內文', '關鍵字'])
  # 寫入內容資料
  writer.writerow([title, time, content, keywords])

# %%
# 用逗號分割開來
keywords.split(",")
# Out:
# ['鴻海', '富士康', '5G', '毫米波', '連接器', '工業富聯']

# %%
import csv

with open('output.csv', 'w', encoding="utf-8") as f:
  # 建立 CSV 寫入器
  writer = csv.writer(f)

  # 寫入標頭資料
  writer.writerow(['標題', '發文時間', '內文', '關鍵字'])
  # 寫入內容資料
  for keyword in keywords.split(","):
    writer.writerow([title, time, content, keyword])

# %% [markdown]
# ## 將股市新聞爬蟲程式，包裝成 function

# %%
def cnyes_news_crawler(url, filename):
  ###url = "https://news.cnyes.com/news/id/4513215?exp=a"
  res = requests.get(url)
  soup = BeautifulSoup(res.text)
  title = soup.find("h1").text
  print(title)
  time = soup.find("time").text
  print(time)
  body_div = soup.find("div", {"itemprop":"articleBody"})
  body_div.find_all("p")
  content = ""
  for p in body_div.find_all("p"):
    content = content + p.text.strip().replace("<br>", "")
  print(content)
  keywords = soup.find("meta", {"itemprop":"keywords"})["content"]
  print(keywords)

  ###with open('output.csv', 'w', encoding="utf-8") as f:
  with open(filename, 'w', encoding='utf-8') as f:
    # 建立 CSV 寫入器
    writer = csv.writer(f)

    # 寫入標頭資料
    writer.writerow(['標題', '發文時間', '內文', '關鍵字'])
    # 寫入內容資料
    for keyword in keywords.split(","):
      writer.writerow([title, time, content, keyword])

# %%
# 爬取普鴻鉅亨網的新聞
url = "https://news.cnyes.com/news/id/4259312"
filename = "普鴻test.csv"
cnyes_news_crawler(url, filename)
# Out:
# 普鴻上櫃首日蜜月行情甜 漲幅最高達98%
# 2018/12/24 12:34
# 國內金融支付系統龍頭廠普鴻資訊 (6590-TW) 今 (24) 日掛牌上櫃，承銷價為每股 19.15 元，股價開盤隨即衝高至 38 元，漲幅高達 98%，盤中漲幅雖稍微收斂，但仍維持約 6 成漲幅，蜜月行情甜。受一例一休影響，普鴻去年前 3 季營運表現不佳，不過，第 4 季起在軟體提升專案帶動下，營運表現回溫，去年全年每股純益達 1.32 元。今年起在調整相關報價與定價後，原先的人事費用已成功反映，毛利率回升至超過 3 成，營運相對持穩，前 3 季每股純益已達 1.3 元，接近去年全年獲利表現。展望明年，普鴻董事長林群國表示，銀行業者編列預算的時間通常為年底前，因此，明年普鴻的專案訂單已取得約 5 至 6 成，對明年營運展望樂觀看待，他也說，銀行客戶風險係數不高，營運預期將持穩，而普鴻成長雙引擎之一為技術與商業模式創新，另一引擎則為透過併購與投資以取得客戶。普鴻成立於 2000 年，實收資本額為新台幣 1.3 億元，主要業務為提供國內外金融業者整合性金融資訊服務，包括金融支付、電子支付、資訊安全等服務，目前主要客戶包括台灣銀行、中國信託、合作金庫、北富銀、星展銀行與花旗銀行等。在財金支付、企業支付產品、票交所代收代付領域為市佔率最高的業者。普鴻今年前 3 季營收 2.38 億元，年增 22.8%，毛利率 32.42%，年增 4.08 個百分點，營益率 8.89%，較去年同期的 - 0.22% 轉正；稅後純益 1688.4 萬元，較去年同期轉盈，每股稅後純益 1.3 元。
# 普鴻,資訊,金融支付,股價,蜜月,上櫃,掛牌,資訊服務,承銷價

# %% [markdown]
# ## 取得股市新聞列表

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.cnyes.com/news/cat/tw_stock"
res = requests.get(url)

# %%
res.text
# Out:
# '<!doctype html>\n<html lang="zh-TW" data-reactroot="" data-reactid="1" data-react-checksum="-1753775965"><head data-reactid="2"><meta charset="utf-8" data-reactid="3"/><script data-reactid="4">(function setupTitleExp(a,b,c,d,e){function pickBall(a){var b=Math.random();return b<=a?b<=a/2?\'a\':\'b\':\'o\'}function bakeCookie(a,_ref){var b=_ref.name,c=_ref.value,e=_ref.maxAge,f=_ref.domain,g=[b+\'=\'+c,\'path=/\',\'max-age=\'+e,\'domain=\'+f].join(\';\');a.cookie=g}var f=new RegExp(e+\'=([^;]+)\'),g=new RegExp(\'^/news/id/[0-9]+\'),h=a.cookie.match(f),i=h&&(h=h[1]),j=b.search,k=!1;if(!i){var l=b.host,m=l.substring(l.indexOf(\'.\'));i=pickBall(c),bakeCookie(a,{name:e,value:i,maxAge:d,domain:m}),k=!0}if(b.pathname.match(g)&&(k=!1),j.match(/exp=.{1}/)&&(k=!1),k&&(\'a\'===i||\'b\'===i)){j=j.replace(/exp=[ab]/gi,\'\');var n=\'exp=\'+i;b.href=j?j+\'&\'+n:\'?\'+n}})(document, location, 86400000, 0.6, \'__exp__\')</script><meta property="fb:app_id" content="325242790993768" data-reactid="5"/>
# ...

# %%
soup = BeautifulSoup(res.text)

# %%
soup.find_all("a")
# Out:
# [<a class="_1AtfL" data-global-ga-action="click" data-global-ga-category="Logo" data-global-ga-label="home" data-reactid="9" href="https://www.cnyes.com/"></a>,
#  <a class="_3lW78" data-reactid="10" href="/">新聞</a>,
#  <a data-reactid="44" href="https://www.facebook.com/anuetw/" rel="noopener noreferrer" target="_blank">粉絲團</a>,
#  <a class="_2jyB4" data-global-ga-action="click" data-global-ga-category="Nav" data-global-ga-label="首頁" data-reactid="47" href="https://www.cnyes.com/"><!-- react-text: 48 -->首頁<!-- /react-text --></a>,
#  <a class="_2jyB4" data-global-ga-action="click" data-global-ga-category="Nav" data-global-ga-label="新聞" data-reactid="50" href="http://news.cnyes.com/"><!-- react-text: 51 -->新聞<!-- /react-text --><span class="_37HAC" data-reactid="52"></span></a>,
#  <a data-global-ga-action="click" data-global-ga-category="Nav" data-global-ga-label="新聞_頭條" data-reactid="55" href="https://news.cnyes.com/news/cat/headline" title="頭條">頭條</a>,
# ...

# %%
soup.find_all("a", {"class": "_1Zdp"})
# Out:
# [<a class="_1Zdp" data-reactid="236" href="/news/id/4545735" style="display:block;" title="台新銀行未來車站 進駐金融博覽會"><div class="_67tN theme-meta" data-reactid="237"><time data-reactid="238" datetime="2020-11-27T10:09:09+08:00">10:09</time><div class="_jFb7 theme-sub-cat" data-reactid="239">台股新聞</div></div><div class="_1xc2" data-reactid="240"><h3 data-reactid="241">台新銀行未來車站 進駐金融博覽會</h3><figure class="" data-reactid="242"><img alt="" data-reactid="243" src="https://cimg.cnyes.cool/prod/news/4545735/s/cca7922b966d2164f233d6f4d1f4859a.jpg" srcset="https://cimg.cnyes.cool/prod/news/4545735/s/cca7922b966d2164f233d6f4d1f4859a.jpg 1x,https://cimg.cnyes.cool/prod/news/4545735/m/cca7922b966d2164f233d6f4d1f4859a.jpg 2x,https://cimg.cnyes.cool/prod/news/4545735/l/cca7922b966d2164f233d6f4d1f4859a.jpg 3x"/><!-- react-text: 244 --><!-- /react-text --></figure></div></a>,
# ...

# %%
news_list = soup.find_all("a", {"class": "_1Zdp"})

# %%
# 用len來看看收集到幾則新聞
len(news_list)
# Out:
# 17

# %%
news_list[0]["href"]
# Out:
# '/news/id/4545735'

# %%
urls = []
# 把新聞列表裡面每一則新聞的網址都用append塞進urls的空白清單中
for item in news_list:
  urls.append(item["href"])
urls
# Out:
# ['/news/id/4545735',
#  '/news/id/4545688',
#  '/news/id/4545680',
#  '/news/id/4545669',
#  '/news/id/4545667',
#  '/news/id/4545668',
#  '/news/id/4545656',
#  '/news/id/4545597',
#  '/news/id/4545560',
#  '/news/id/4545651',
#  '/news/id/4545649',
#  '/news/id/4545648',
#  '/news/id/4545646',
#  '/news/id/4545643',
#  '/news/id/4545644',
#  '/news/id/4545642',
#  '/news/id/4545640']

# %%
# 將url組合主網域
"https://news.cnyes.com" + urls[0]
# Out:
# 'https://news.cnyes.com/news/id/4545735'

# %%
# 將多筆url餵給單則新聞爬蟲程式
import requests
from bs4 import BeautifulSoup

for url in urls[:5]: # 簡單測試，只取列表中前五筆新聞  
  url = "https://news.cnyes.com" + url
  print(url)
  # 單則新聞爬蟲程式
  cnyes_news_crawler(url, "output.csv")
# Out:
# https://news.cnyes.com/news/id/4545735
# 台新銀行未來車站 進駐金融博覽會
# 2020/11/27 10:09
# ...

# %%
## 食緊挵破碗，睡一下！休息一下
import time
time.sleep(3)
print("OK")
# Out:
# OK

# %%
import requests
import time
from bs4 import BeautifulSoup

for url in urls[:5]: # 測試，只取列表中前五筆新聞  
  url = "https://news.cnyes.com" + url
  print(url)
  # 單則新聞爬蟲程式
  cnyes_news_crawler(url, "output.csv")
  time.sleep(2)
# Out:
# https://news.cnyes.com/news/id/4545735
# 台新銀行未來車站 進駐金融博覽會
# 2020/11/27 10:09
# ...

# %% [markdown]
# ## 透過 ajax 取得完整股市新聞列表

# %%
import requests
from bs4 import BeautifulSoup

url = "https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?limit=30&startAt=1595952000&endAt=1596902399&page=2"
res = requests.get(url)

# %%
res.text
# Out:
# '{"items":{"total":621,"per_page":30,"current_page":2,"last_page":21,"next_page_url":"\\/media\\/api\\/v1\\/newslist\\/category\\/tw_stock?startAt=1595952000&endAt=1596902399&limit=30&page=3","prev_page_url":"\\/media\\/api\\/v1\\/newslist\\/category\\/tw_stock?startAt=1595952000&endAt=1596902399&limit=30&page=1","from":31,"to":60,"data":[{"content":"&lt;p&gt;\\u7d93\\u6fdf\\u90e8\\u5de5\\u696d\\u5c40\\u8207\\u601d\\u79d1 (CSCO-US) \\u5171\\u540c\\u6253\\u9020\\u5168\\u53f0\\u9996\\u5ea7 5G \\u958b\\u653e\\u7db2\\u8def\\u6aa2\\u6e2c\\u5e73\\u53f0\\uff0c\\u884c\\u653f\\u9662\\u79d1\\u6280\\u6703\\u5831\\u57f7\\u884c\\u79d8\\u66f8\\u8521\\u5fd7\\u5b8f\\u5206\\u6790\\uff0c\\u53f0\\u7063\\u5728 5G \\u958b\\u653e\\u5e73\\u53f0\\u63a8\\u52d5\\u4e0a\\u5177\\u6709\\u4e09\\u5927\\u512a\\u52e2\\uff0c\\u5305\\u542b\\u5177\\u6709\\u5b8c\\u6574\\u7522\\u696d\\u4f9b\\u61c9\\u93c8\\u3001\\u4eba\\u624d\\u3001\\u5c0d\\u65b0\\u61c9\\u7528\\u958b\\u653e\\u7b49\\uff0c\\u53f0\\u7063\\u7d44\\u88dd\\u4ee3\
# ...

# %%
# 將 json 格式的字串，轉換成 dictionary
res.json()
# Out:
# {'items': {'current_page': 2,
#   'data': [{'abTesting': None,
#     'categoryId': 827,
#     'categoryName': '台股新聞',
#     'columnists': None,
#     'content': '&lt;p&gt;經濟部工業局與思科 (CSCO-US) 共同打造全台首座 5G 開放網路檢測平台，行政院科技會報執行秘書蔡志宏分析，台灣在 5G 開放平台推動上具有三大優勢，包含具有完整產業供應鏈、人才、對新應用開放等，台灣組裝代工、網通廠也看準商機，積極布局。&lt;/p&gt;\n\n&lt;p&gt;蔡志宏表示，台灣從半導體、個人電腦產業發展，具備完整產業供應鏈，在 5G 發展上，包含伺服器、基站所需的 RF 天線、驗證設備都相當完整，具有客製化產業生態體系，而台灣工程技術人員也獲國際大廠信賴，加上台灣數位化進程快，對新應用持開放態度。&lt;/p&gt;\n\n&lt;p&gt;蔡志宏進一步指出，台灣已針對展演空間、遠距醫療、遠距學習等場域進行 5G 試驗，隨著 5G 開放架構逐步成熟後，台灣可望快速整合軟硬體，將各領域服務落地。&lt;/p&gt;\n\n&lt;p&gt;觀察台廠&amp;nbsp;5G 網通設備，除電信商外，組裝代工廠和碩 (4938-TW)、英業達 (2356-TW)、仁寶 (2324-TW) 等都有布局，包括網通設備廠智邦 (2345-TW)、明泰 (3380-TW)、智易 (3596-TW)、亞旭、中磊 (5388-TW)、正文 (4906-TW)、伸波通訊、台灣可億隆、優達科技等，以及系統整合商華電聯網 (6163-TW) 等皆有參與，其中，部分廠商更已參與國際開放網路架構組織 O-RAN、TIP 等。&lt;/p&gt;\n\n&lt;p&gt;台灣政府也持續推動 5G 發展，國發會主委龔明鑫指出，因應 5G 布局，去年就第 1 期 5G 行動方案已投入 204 億元，支援頻譜設計、前瞻技術研發等，近期在前瞻基礎建設上，也匡列約 500 億元經費，加上經濟部大 A + 計劃等其他部會投入，估整體已投入約 700-800 億元經費。&lt;/p&gt;\n',
# ...

# %%
data = res.json()

# %%
# 變成 dictionary後，就可以自由存取裡面的資料
data["message"]
# Out:
# '成功'

# %%
# 取出新聞列表資料
data["items"]
# Out:
# {'current_page': 2,
#  'data': [{'abTesting': None,
#    'categoryId': 827,
#    'categoryName': '台股新聞',
#    'columnists': None,
#    'content': '&lt;p&gt;經濟部工業局與思科 (CSCO-US) 共同打造全台首座 5G 開放網路檢測平台，行政院科技會報執行秘書蔡志宏分析，台灣在 5G 開放平台推動上具有三大優勢，包含具有完整產業供應鏈、人才、對新應用開放等，台灣組裝代工、網通廠也看準商機，積極布局。&lt;/p&gt;\n\n&lt;p&gt;蔡志宏表示，台灣從半導體、個人電腦產業發展，具備完整產業供應鏈，在 5G 發展上，包含伺服器、基站所需的 RF 天線、驗證設備都相當完整，具有客製化產業生態體系，而台灣工程技術人員也獲國際大廠信賴，加上台灣數位化進程快，對新應用持開放態度。&lt;/p&gt;\n\n&lt;p&gt;蔡志宏進一步指出，台灣已針對展演空間、遠距醫療、遠距學習等場域進行 5G 試驗，隨著 5G 開放架構逐步成熟後，台灣可望快速整合軟硬體，將各領域服務落地。&lt;/p&gt;\n\n&lt;p&gt;觀察台廠&amp;nbsp;5G 網通設備，除電信商外，組裝代工廠和碩 (4938-TW)、英業達 (2356-TW)、仁寶 (2324-TW) 等都有布局，包括網通設備廠智邦 (2345-TW)、明泰 (3380-TW)、智易 (3596-TW)、亞旭、中磊 (5388-TW)、正文 (4906-TW)、伸波通訊、台灣可億隆、優達科技等，以及系統整合商華電聯網 (6163-TW) 等皆有參與，其中，部分廠商更已參與國際開放網路架構組織 O-RAN、TIP 等。&lt;/p&gt;\n\n&lt;p&gt;台灣政府也持續推動 5G 發展，國發會主委龔明鑫指出，因應 5G 布局，去年就第 1 期 5G 行動方案已投入 204 億元，支援頻譜設計、前瞻技術研發等，近期在前瞻基礎建設上，也匡列約 500 億元經費，加上經濟部大 A + 計劃等其他部會投入，估整體已投入約 700-800 億元經費。&lt;/p&gt;\n',
# ...

# %%
news_list = data["items"]["data"]

# %%
ids = []
for item in news_list:
  ids.append(item["newsId"])
ids
# Out:
# [4513047,
#  4513052,
#  4513049,
#  4513045,
#  4513046,
#  4513043,
#  4513044,
#  4513032,
#  4513034,
#  4513030,
#  4513029,
#  4512969,
#  4513028,
#  4512971,
#  4512968,
#  4512871,
#  4512868,
#  4512865,
#  4512858,
#  4512854,
#  4512748,
#  4512747,
#  4512730,
#  4512734,
#  4512726,
#  4512719,
#  4512728,
#  4512721,
#  4512725,
#  4512481]

# %%
# 組合字串 - string formatting
nid = ids[0]

# %%
#"https://news.cnyes.com/news/id/" + nid + "?exp=a"

# %%
url = f"https://news.cnyes.com/news/id/{nid}?exp=a"
url
# Out:
# 'https://news.cnyes.com/news/id/4513047?exp=a'

# %%
for nid in ids:
  url = f"https://news.cnyes.com/news/id/{nid}?exp=a"
  print(url)
# Out:
# https://news.cnyes.com/news/id/4513047?exp=a
# https://news.cnyes.com/news/id/4513052?exp=a
# https://news.cnyes.com/news/id/4513049?exp=a
# https://news.cnyes.com/news/id/4513045?exp=a
# https://news.cnyes.com/news/id/4513046?exp=a
# https://news.cnyes.com/news/id/4513043?exp=a
# https://news.cnyes.com/news/id/4513044?exp=a
# https://news.cnyes.com/news/id/4513032?exp=a
# https://news.cnyes.com/news/id/4513034?exp=a
# https://news.cnyes.com/news/id/4513030?exp=a
# https://news.cnyes.com/news/id/4513029?exp=a
# https://news.cnyes.com/news/id/4512969?exp=a
# https://news.cnyes.com/news/id/4513028?exp=a
# https://news.cnyes.com/news/id/4512971?exp=a
# https://news.cnyes.com/news/id/4512968?exp=a
# https://news.cnyes.com/news/id/4512871?exp=a
# https://news.cnyes.com/news/id/4512868?exp=a
# https://news.cnyes.com/news/id/4512865?exp=a
# https://news.cnyes.com/news/id/4512858?exp=a
# https://news.cnyes.com/news/id/4512854?exp=a
# https://news.cnyes.com/news/id/4512748?exp=a
# ...

# %%
# 藉由 next_page_url 來換頁
data["items"]["next_page_url"]
# Out:
# '/media/api/v1/newslist/category/tw_stock?startAt=1595952000&endAt=1596902399&limit=30&page=3'

# %%
"https://api.cnyes.com" + data["items"]["next_page_url"]
# Out:
# 'https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?startAt=1595952000&endAt=1596902399&limit=30&page=3'

# %%
import requests
from bs4 import BeautifulSoup

url = "https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?limit=30&startAt=1595952000&endAt=1596902399&page=2"
res = requests.get(url)
data = res.json()
news_list = data["items"]["data"]
ids = []
for item in news_list:
  ids.append(item["newsId"])

counter = 0
while "next_page_url" in data["items"]:
  url = "https://api.cnyes.com" + data["items"]["next_page_url"]
  print(url)
  res = requests.get(url)
  data = res.json()
  news_list = data["items"]["data"]
  for item in news_list:
    ids.append(item["newsId"])

  # demo專用，換5頁後強迫停止
  counter += 1
  if counter >= 5:
    break
# Out:
# https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?startAt=1595952000&endAt=1596902399&limit=30&page=3
# https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?startAt=1595952000&endAt=1596902399&limit=30&page=4
# https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?startAt=1595952000&endAt=1596902399&limit=30&page=5
# https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?startAt=1595952000&endAt=1596902399&limit=30&page=6
# https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?startAt=1595952000&endAt=1596902399&limit=30&page=7

# %%
ids
# Out:
# [4513047,
#  4513052,
#  4513049,
#  4513045,
#  4513046,
#  4513043,
#  4513044,
#  4513032,
#  4513034,
#  4513030,
#  4513029,
#  4512969,
#  4513028,
#  4512971,
#  4512968,
#  4512871,
#  4512868,
#  4512865,
#  4512858,
#  4512854,
#  4512748,
#  4512747,
#  4512730,
#  4512734,
#  4512726,
#  4512719,
#  4512728,
#  4512721,
#  4512725,
#  4512481,
#  4512444,
#  4512459,
#  4512483,
#  4512484,
#  4512480,
#  4512446,
#  4512445,
#  4512448,
#  4512437,
#  4512431,
#  4512423,
#  4512413,
#  4512412,
#  4512398,
#  4512400,
#  4512372,
#  4512370,
#  4512368,
#  4512357,
#  4512281,
#  4512279,
#  4512278,
#  4512268,
#  4512272,
#  4512209,
#  4512204,
#  4512202,
#  4512200,
#  4512198,
#  4512196,
#  4512229,
#  4512228,
#  4512224,
#  4512225,
#  4512222,
#  4512223,
#  4512219,
#  4512195,
#  4512185,
#  4512194,
#  4512181,
#  4512180,
#  4512179,
#  4512176,
#  4512177,
#  4512173,
#  4512170,
#  4512171,
#  4512162,
#  4512165,
#  4512163,
#  4512161,
#  4512160,
# ...

# %%
# API 參數 - page & timestamp

url = "https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?limit=30&startAt=1595952000&endAt=1596902399&page=2"

# %%
import time

time.time()
# Out:
# 1606443425.527714

# %%
end = int(time.time())

# %%
start = end - 3600

# %%
url = f"https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?limit=30&startAt={start}&endAt={end}&page=1"
url
# Out:
# 'https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?limit=30&startAt=1606439825&endAt=1606443425&page=1'

# %%
# 彙總爬取股市新聞列表爬蟲程式

import requests
import time
from bs4 import BeautifulSoup

end = int(time.time())
start = end - 3600

url = f"https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?limit=30&startAt={start}&endAt={end}&page=1"
print(url)
res = requests.get(url)
data = res.json()
news_list = data["items"]["data"]
ids = []
for item in news_list:
  ids.append(item["newsId"])
ids
# Out:
# https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?limit=30&startAt=1606439825&endAt=1606443425&page=1
# [4545735,
#  4545709,
#  4545708,
#  4545707,
#  4545705,
#  4545704,
#  4545703,
#  4545702,
#  4545701,
#  4545700,
#  4545699,
#  4545688,
#  4545691,
#  4545689,
#  4545680,
#  4545669]

# %% [markdown]
# ## 將新聞列表爬蟲程式，包裝成 function

# %%
def cnyes_list_crawler():
  end = int(time.time())
  start = end - 3600

  url = f"https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?limit=30&startAt={start}&endAt={end}&page=1"
  print(url)
  res = requests.get(url)
  data = res.json()
  news_list = data["items"]["data"]
  ids = []
  for item in news_list:
    ids.append(item["newsId"])
  return ids

# %% [markdown]
# ## 整合兩步驟爬蟲 - 取得新聞列表 -> 爬取新聞內容資料

# %%
import requests
import time
from bs4 import BeautifulSoup

ids = cnyes_list_crawler()
for nid in ids:
  url = f"https://news.cnyes.com/news/id/{nid}?exp=a"
  filename = f"{nid}.csv"
  cnyes_news_crawler(url, filename)
  time.sleep(2)
# Out:
# https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?limit=30&startAt=1606439825&endAt=1606443425&page=1
# 台新銀行未來車站 進駐金融博覽會
# 2020/11/27 10:09
# ...

# %%
# 導入 模組(module) 
import requests 
# 導入 BeautifulSoup 模組(module)：解析HTML 語法工具
import bs4

# 文章連結
URL = "https://www.ptt.cc/bbs/Gossiping/M.1590678355.A.246.html"
# 設定Header與Cookie
my_headers = {'cookie': 'over18=1;'}
# 發送get 請求 到 ptt 八卦版
response = requests.get(URL, headers = my_headers)


#  把網頁程式碼(HTML) 丟入 bs4模組分析
soup = bs4.BeautifulSoup(response.text,"html.parser")

## PTT 上方4個欄位
header = soup.find_all('span','article-meta-value')

# 作者
author = header[0].text
# 看版
board = header[1].text
# 標題
title = header[2].text
# 日期
date = header[3].text


## 查找所有html 元素 抓出內容
main_container = soup.find(id='main-container')
# 把所有文字都抓出來
all_text = main_container.text
# 把整個內容切割透過 "-- " 切割成2個陣列
pre_text = all_text.split('--')[0]
    
# 把每段文字 根據 '\n' 切開
texts = pre_text.split('\n')
# 如果你爬多篇你會發現 
contents = texts[2:]
# 內容
content = '\n'.join(contents)


# 顯示
print('作者：'+author)
print('看板：'+board)
print('標題：'+title)
print('日期：'+date)
print('內容：'+content)
# Out:
# 作者：touchBB (CK)
# 看板：Gossiping
# 標題：[問卦] 有兩千萬現金 可以退休嗎?
# 日期：Thu May 28 23:05:53 2020
# 內容：我朋友34歲
#
# 最近拿到一筆遺產
#
# 大概1700萬現金 300萬珠寶黃金首飾....等
#
# 還有一戶無貸款老屋
#
#
# 他說想拿2000萬好好投資
#
# 然後退休
#
# 有可能嗎?
